# %%
import os
from dotenv import load_dotenv
from qdrant_client import QdrantClient
from openai import OpenAI

# Load environment variables from .env
load_dotenv()

QDRANT_URL = os.getenv("QDRANT_URL")
QDRANT_API_KEY = os.getenv("QDRANT_API_KEY")
COLLECTION_NAME = os.getenv("QDRANT_COLLECTION_NAME")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

print("QDRANT_URL:", QDRANT_URL)
print("COLLECTION_NAME:", COLLECTION_NAME)
# Out:
# QDRANT_URL: https://5d9836f1-dece-45c3-a44b-fd0b1d0c053e.us-west-2-0.aws.cloud.qdrant.io:6333
# COLLECTION_NAME: rice_knowledge_chunks

# %%
import os
from pathlib import Path

# Load environment variables manually from .env
env_path = Path('.') / '.env'
if env_path.exists():
    with open(env_path) as f:
        for line in f:
            if '=' in line and not line.strip().startswith('#'):
                key, value = line.strip().split('=', 1)
                os.environ[key] = value

QDRANT_URL = os.environ.get("QDRANT_URL")
QDRANT_API_KEY = os.environ.get("QDRANT_API_KEY")
COLLECTION_NAME = os.environ.get("QDRANT_COLLECTION_NAME")
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")

print("QDRANT_URL:", QDRANT_URL)
print("COLLECTION_NAME:", COLLECTION_NAME)

# Print if API keys loaded
print("QDRANT_API_KEY is set:", bool(QDRANT_API_KEY))
print("OPENAI_API_KEY is set:", bool(OPENAI_API_KEY))
# Out:
# QDRANT_URL: https://5d9836f1-dece-45c3-a44b-fd0b1d0c053e.us-west-2-0.aws.cloud.qdrant.io:6333
# COLLECTION_NAME: rice_knowledge_chunks
# QDRANT_API_KEY is set: True
# OPENAI_API_KEY is set: True

# %%
# Define retrieval functions (requires qdrant_client and openai installed)
# The following code won't run here because the packages are not installed.
from qdrant_client import QdrantClient
from openai import OpenAI


def get_query_embedding(text: str) -> list:
    """Get OpenAI embedding for a text query."""
    client = OpenAI(api_key=OPENAI_API_KEY)
    response = client.embeddings.create(
        model="text-embedding-3-small",
        input=text
    )
    return response.data[0].embedding


def retrieve_chunks(query: str, k: int = 5, threshold: float = 0.35) -> list:
    """Semantic search from Qdrant with full payloads."""
    # Initialize Qdrant client
    client = QdrantClient(
        url=QDRANT_URL,
        api_key=QDRANT_API_KEY
    )
    query_vector = get_query_embedding(query)

    results = client.search(
        collection_name=COLLECTION_NAME,
        query_vector=query_vector,
        limit=k,
        with_payload=True,
        with_vectors=False
    )

    chunks = []
    for r in results:
        payload = r.payload or {}
        chunks.append({
            'score': r.score,
            'content': payload.get('content', ''),
            'title': payload.get('title', ''),
            'summary': payload.get('summary', ''),
            'url': payload.get('url', ''),
            'source': payload.get('source', ''),
            'chunk_id': payload.get('chunk_id', ''),
        })
    # Optionally filter by threshold
    return [c for c in chunks if c['score'] >= threshold]

# %%
# Cell 1: Imports and environment setup
import os
from pathlib import Path
from typing import List, Dict
from dotenv import load_dotenv
from qdrant_client import QdrantClient

from langchain.schema import Document
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain_core.retrievers import BaseRetriever
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain import hub

from openai import OpenAI

# Load environment variables
load_dotenv()
env_path = Path('.') / '.env'
if env_path.exists():
    with open(env_path) as f:
        for line in f:
            if '=' in line and not line.strip().startswith('#'):
                key, value = line.strip().split('=', 1)
                os.environ.setdefault(key, value)

QDRANT_URL = os.environ.get("QDRANT_URL")
QDRANT_API_KEY = os.environ.get("QDRANT_API_KEY")
COLLECTION_NAME = os.environ.get("QDRANT_COLLECTION_NAME")
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")

# Initialize clients
qdrant = QdrantClient(url=QDRANT_URL, api_key=QDRANT_API_KEY)
openai_client = OpenAI(api_key=OPENAI_API_KEY)

# Helper: embed the query
def get_query_embedding(text: str) -> List[float]:
    resp = openai_client.embeddings.create(
        model="text-embedding-3-small",
        input=text
    )
    return resp.data[0].embedding

# %%
# Cell 2: Retrieval function using qdrant.search()
def retrieve_chunks(query: str, k: int = 5, threshold: float = 0.35) -> List[Document]:
    """
    Use the deprecated search() API to retrieve the top-k chunks and return them as LangChain Documents.
    Each Document has page_content set to the chunk text and metadata containing score, title, summary, etc.
    """
    query_vec = get_query_embedding(query)
    results = qdrant.search(
        collection_name=COLLECTION_NAME,
        query_vector=query_vec,
        limit=k,
        with_payload=True,
        with_vectors=False,
        score_threshold=threshold
    )

    docs: List[Document] = []
    for r in results:
        payload: Dict = r.payload or {}
        docs.append(
            Document(
                page_content=payload.get("content", ""),
                metadata={
                    "score": r.score,
                    "title": payload.get("title", ""),
                    "summary": payload.get("summary", ""),
                    "url": payload.get("url", ""),
                    "source": payload.get("source", ""),
                    "chunk_id": payload.get("chunk_id", ""),
                }
            )
        )
    return docs

# %%
# Cell 3: Custom Retriever for LangChain
class QdrantSearchRetriever(BaseRetriever):
    """A LangChain-compatible retriever that uses Qdrant's search() API."""
    k: int = 5
    threshold: float = 0.35

    def _get_relevant_documents(self, query: str, **kwargs) -> List[Document]:
        return retrieve_chunks(query, k=self.k, threshold=self.threshold)

# %%
# from langchain_core.prompts import ChatPromptTemplate
#
#
# # We assume retrieve_chunks() already returns a List[Document] with metadata.
# # If it still returns dictionaries, wrap each dict in a Document first.
#
# def qa_with_sources(
#     question: str,
#     k: int = 5,
#     threshold: float = 0.35,
# ) -> dict:
#     """
#     Retrieve context from Qdrant and generate a detailed answer.
#     Return both the answer text and the list of source documents.
#     """
#     docs = retrieve_chunks(question, k=k, threshold=threshold)  # List[Document]
#     context = "\n\n".join(doc.page_content for doc in docs)
#
#     # Build your detailed prompt
#     detailed_prompt = ChatPromptTemplate.from_template(
#         """
#         You are RiceAI Expert, a trusted agronomist and AI agent trained on sustainable
#         and high-yield rice farming practices.
#
#         Use all relevant information from the context provided, and write a thorough,
#         step-by-step answer that explains the key points and their significance.
#
#         Context:
#         {context}
#
#         Question:
#         {question}
#
#         Detailed Answer:
#         """
#     )
#
#     chat = ChatOpenAI(
#         model="gpt-4o-mini",
#         temperature=0,
#         openai_api_key=OPENAI_API_KEY
#     )
#     answer = chat.invoke(
#         detailed_prompt.format(context=context, question=question)
#     ).content
#
#     return {"answer": answer, "source_documents": docs}
#
# # Example usage:
# result = qa_with_sources("What are the key factors affecting organic fertilizer adoption in rice production?")
# print(result["answer"])
# for doc in result["source_documents"]:
#     print(doc.metadata["title"], doc.metadata["url"])
# Out:
# C:\Users\shant\AppData\Local\Temp\ipykernel_37208\2086247675.py:8: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   results = qdrant.search(
# The adoption of organic fertilizers in rice production is influenced by a variety of factors, as highlighted in the provided context. Understanding these factors is crucial for promoting sustainable agricultural practices and improving the financial efficiency of rice farming. Below is a detailed, step-by-step explanation of the key factors affecting organic fertilizer adoption:
#
# ### 1. **Education Level**
#    - **Significance**: Higher education levels among farmers positively correlate with the adoption of organic fertilizers. Educated farmers are more likely to understand the benefits of organic farming practices and are better equipped to implement them effectively.
#    - **Implication**: Educational programs and training on organic farming practices can enhance farmers' knowledge and encourage the use of organic fertilizers.
#
# ### 2. **Main Job**
#    - **Significance**: Farmers whose primary occupation is rice production are more inclined to use organic fertilizers compared to those engaged in other professions. This is likely due to a stronger commitment to improving their rice yields and sustainability practices.
#    - **Implication**: Targeting rice farmers specifically with organic fertilizer initiatives can lead to higher adoption rates.
#
# ### 3. **Participation in Farmers’ Associations**
#    - **Significance**: Membership in farmers' associations positively impacts the likelihood of adopting organic fertilizers. These associations often provide resources, support, and shared knowledge about sustainable practices.
#    - **Implication**: Encouraging farmers to join associations can facilitate the dissemination of information and resources related to organic farming.
#
# ### 4. **Household Size**
#    - **Significance**: Larger households tend to adopt organic fertilizers more frequently. This may be due to the availability of more labor and resources to manage organic farming practices.
#    - **Implication**: Policies that support larger farming families in accessing organic fertilizers could enhance adoption rates.
#
# ### 5. **Ethnicity**
#    - **Significance**: The study indicates that the Kinh ethnic group is less likely to adopt organic fertilizers compared to other ethnic groups. This may be attributed to cultural practices and preferences for conventional farming methods.
#    - **Implication**: Tailored outreach and education efforts that respect and incorporate cultural practices of different ethnic groups may improve adoption rates.
#
# ### 6. **Access to Credit**
#    - **Significance**: Farmers with access to credit are less likely to use organic fertilizers. This may be because they prefer to invest in inorganic fertilizers, which are often perceived as more effective and easier to apply.
#    - **Implication**: Financial incentives or subsidies for organic fertilizers could encourage farmers to shift from inorganic to organic options.
#
# ### 7. **Rice Acreage**
#    - **Significance**: Farmers with larger rice acreage are less likely to adopt organic fertilizers. The bulkiness and limited supply of organic fertilizers make them less practical for large-scale applications.
#    - **Implication**: Developing industrial organic fertilizers that can be used efficiently on larger scales could help overcome this barrier.
#
# ### 8. **Financial Indicators**
#    - **Yield and Profitability**: The study shows that while the yield and revenue from inorganic fertilizer use are higher, the profit margins are similar between the two groups. The Return on Sales (ROS) index is higher for those using organic fertilizers, indicating better financial efficiency.
#    - **Implication**: Highlighting the financial benefits of organic fertilizers, such as improved ROS, can motivate farmers to adopt these practices.
#
# ### 9. **Supply of Organic Fertilizers**
#    - **Significance**: The limited supply of organic fertilizers, with 85% being self-sufficient, poses a challenge for widespread adoption. Farmers often rely on traditional methods and may lack access to industrial organic fertilizers.
#    - **Implication**: Government policies should focus on increasing the availability and accessibility of organic fertilizers to encourage their use.
#
# ### Conclusion
# The adoption of organic fertilizers in rice production is influenced by a complex interplay of educational, social, economic, and cultural factors. By addressing these factors through targeted education, financial support, and improved access to organic fertilizers, stakeholders can promote sustainable agricultural practices that enhance both productivity and environmental health in rice farming.
# Factors Affecting Organic Fertilizer Adoption in Rice Production in Vietnam https://drive.google.com/file/d/16ttkddPVPgKkXupcrgsbkMZn87Rt9CRk/view?usp=drive_link
# Factors Influencing Organic Fertilizer Use in Rice Cultivation in Vietnam https://drive.google.com/file/d/16ttkddPVPgKkXupcrgsbkMZn87Rt9CRk/view?usp=drive_link
# Factors Affecting Organic Fertilizer Adoption in Rice Production in Vietnam https://drive.google.com/file/d/16ttkddPVPgKkXupcrgsbkMZn87Rt9CRk/view?usp=drive_link
# Challenges in Organic Fertilizer Adoption for Rice Production in Vietnam https://drive.google.com/file/d/16ttkddPVPgKkXupcrgsbkMZn87Rt9CRk/view?usp=drive_link
# Factors Influencing Organic Fertilizer Adoption in Rice Production in Vietnam https://drive.google.com/file/d/16ttkddPVPgKkXupcrgsbkMZn87Rt9CRk/view?usp=drive_link

# %%
from langchain.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

# Step 1: Define your detailed prompt (unchanged)
prompt = ChatPromptTemplate.from_template(
    """
    You are RiceAI Expert, a trusted agronomist and AI agent trained on sustainable and high-yield rice farming practices.

    When answering the question, use all relevant context provided. Explain the answer thoroughly and cover all key details, so that no important information is omitted. Be explicit and comprehensive.

    Context:
    {context}

    Question: {question}

    Detailed Answer:
    """
)

def format_docs(docs: List[Document]) -> str:
    return "\n\n".join(doc.page_content for doc in docs)

# Step 2: Instantiate the retriever (using search)
retriever = QdrantSearchRetriever(k=5, threshold=0.35)

# Step 3: Build the chain to get the answer only
qa_chain = (
    {
        "context": retriever | format_docs,
        "question": RunnablePassthrough(),
    }
    | prompt
    | ChatOpenAI(model="gpt-4o-mini", temperature=0, openai_api_key=OPENAI_API_KEY)
    | StrOutputParser()
)

# Step 4: When you have a query, call both qa_chain and retriever
query = input("Enter your question: ").strip()

# Get the answer text
answer_text = qa_chain.invoke(query)

# Get the underlying documents with metadata
docs = retriever.invoke(query)

# Step 5: Display answer and formatted sources
print("### Answer:\n")
print(answer_text, "\n")

if docs:
    print("### Retrieved Sources:\n")
    for i, doc in enumerate(docs, 1):
        meta = doc.metadata
        title = meta.get("title", "No title")
        url = meta.get("url", "No URL")
        score = meta.get("score", 0.0)
        summary = meta.get("summary") or doc.page_content[:200] + "..."
        print(f"{i}. **{title}** (score: {score:.3f})")
        print(f"   URL: {url}")
        print(f"   Summary: {summary}\n")
else:
    print("No sources retrieved.")
# Out:
# C:\Users\shant\AppData\Local\Temp\ipykernel_37208\2086247675.py:8: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   results = qdrant.search(
# C:\Users\shant\AppData\Local\Temp\ipykernel_37208\2086247675.py:8: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   results = qdrant.search(
# ### Answer:
#
# Mechanized techniques for water management in rice farming are essential for enhancing efficiency, reducing labor costs, and optimizing water use. Here are several mechanized approaches that can be employed in rice cultivation, particularly in conjunction with practices like Alternate Wetting and Drying (AWD):
#
# ### 1. **Laser Land Leveling**
#    - **Description**: Laser land leveling involves using laser-guided equipment to create a uniformly leveled field. This technique minimizes water pooling and ensures even water distribution across the field.
#    - **Benefits**: A well-leveled field can reduce water requirements by 80-100 mm, as it prevents excess water from accumulating in low spots and ensures that all areas receive adequate irrigation.
#
# ### 2. **Automated Irrigation Systems**
#    - **Description**: These systems use sensors and timers to automate the irrigation process. Soil moisture sensors can detect when the soil reaches a certain dryness level and trigger irrigation accordingly.
#    - **Benefits**: Automated systems help in applying water precisely when needed, reducing waste and ensuring that the crop receives optimal moisture levels without over-irrigation.
#
# ### 3. **Drip Irrigation**
#    - **Description**: Although more common in vegetable and fruit crops, drip irrigation can be adapted for rice cultivation in certain contexts. It involves delivering water directly to the root zone through a network of tubing and emitters.
#    - **Benefits**: This method minimizes evaporation and runoff, allowing for significant water savings while maintaining crop health.
#
# ### 4. **Subsurface Irrigation**
#    - **Description**: This technique involves burying irrigation pipes below the soil surface, allowing water to seep directly into the root zone.
#    - **Benefits**: Subsurface irrigation reduces evaporation losses and can be particularly effective in maintaining soil moisture levels during critical growth stages.
#
# ### 5. **Field Water Tubes (Pani Pipes)**
#    - **Description**: While not fully mechanized, the use of field water tubes can be enhanced with technology. These tubes can be equipped with sensors that provide real-time data on water levels.
#    - **Benefits**: This allows farmers to monitor water levels more accurately and make timely irrigation decisions, thus optimizing water use.
#
# ### 6. **Water Pumps and Distribution Systems**
#    - **Description**: Mechanized water pumps can be used to efficiently draw water from sources such as rivers, lakes, or reservoirs. Coupled with a well-designed distribution system, they can ensure that water reaches all parts of the field evenly.
#    - **Benefits**: This reduces the time and labor required for irrigation and can be synchronized with automated systems for better efficiency.
#
# ### 7. **Rotational Irrigation Systems**
#    - **Description**: These systems allow for the controlled distribution of water across different sections of a field, ensuring that water is used efficiently and that all areas receive adequate moisture.
#    - **Benefits**: This method can help manage water resources better, especially in areas with limited water supply.
#
# ### 8. **Drones and Remote Sensing**
#    - **Description**: Drones equipped with sensors can monitor crop health and soil moisture levels across large areas. This data can inform irrigation practices and help in making decisions about when and how much to irrigate.
#    - **Benefits**: By providing precise information, farmers can optimize water use and improve crop yields.
#
# ### 9. **Soil Moisture Management Tools**
#    - **Description**: Mechanized tools that measure soil moisture levels can help farmers determine the best times for irrigation. These tools can be integrated with automated irrigation systems for enhanced efficiency.
#    - **Benefits**: They help in preventing over-irrigation and ensure that crops receive the right amount of water at the right time.
#
# ### Conclusion
# Implementing mechanized techniques for water management in rice farming can significantly enhance water use efficiency, reduce labor costs, and improve crop yields. By integrating these technologies with sustainable practices like AWD, farmers can achieve a balance between water conservation and optimal rice production. It is essential for farmers to assess their specific conditions, including soil type, climate, and water availability, to choose the most suitable mechanized techniques for their operations.
#
# ### Retrieved Sources:
#
# 1. **Saving Water with Alternate Wetting Drying (AWD)** (score: 0.534)
#    URL: http://www.knowledgebank.irri.org/step-by-step-production/growth/water-management/alternate-wetting-drying-awd
#    Summary: Alternate Wetting and Drying (AWD) is a water-saving technique that allows farmers to reduce irrigation water use in rice fields while maintaining yield. This method involves alternating between flooded and non-flooded soil by applying water after the ponded water disappears. Implementation can be aided with a field water tube to monitor water depth.
#
# 2. **Saving Water with Alternate Wetting Drying (AWD) in Rice Cultivation** (score: 0.532)
#    URL: http://www.knowledgebank.irri.org/training/fact-sheets/water-management/saving-water-alternate-wetting-drying-awd
#    Summary: Alternate Wetting and Drying (AWD) is a water management technique that enables rice farmers to decrease irrigation water use without sacrificing yield. This method involves alternating between flooded and non-flooded soil conditions, with irrigation applied after water levels recede. Implementation is facilitated using a 'field water tube' to monitor soil moisture.
#
# 3. **Water Management for Rice Production** (score: 0.516)
#    URL: http://www.knowledgebank.irri.org/step-by-step-production/growth/water-management
#    Summary: The text discusses the importance of water management in rice production, highlighting the water consumption involved in land preparation methods such as puddling and the trade-offs between water use and crop growth. It suggests considering dry land preparation to save water and emphasizes minimizing delays between preparation and planting to optimize water usage in irrigated systems.
#
# 4. **Water Management Practices in Rice Production** (score: 0.512)
#    URL: https://drive.google.com/file/d/1V7f7eQLFvFd4_PR5dUUxTEsPzod1HZj7/view?usp=drive_link
#    Summary: This text discusses the significance of effective water management practices in rice production, highlighting that better water management can reduce the irrigation requirements. It emphasizes that preparing land quickly and choosing early-maturing rice varieties can save significant amounts of water. The document also mentions the benefits of rotational irrigation systems for efficient water distribution.
#
# 5. **Principles and Practices of Rice Production: Irrigation System Design** (score: 0.510)
#    URL: https://drive.google.com/file/d/1V7f7eQLFvFd4_PR5dUUxTEsPzod1HZj7/view?usp=drive_link
#    Summary: The text discusses the interdisciplinary approach required for designing effective irrigation systems in lowland flooded rice production. It highlights the importance of agricultural factors like cropping schedules, labor availability, and varietal moisture response. Cropping schedules are influenced by soil, rainfall, and irrigation water availability, emphasizing the need for precise timing in irrigation to enhance water use efficiency.
